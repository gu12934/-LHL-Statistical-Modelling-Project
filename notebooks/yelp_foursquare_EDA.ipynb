# %% [markdown]
# import libraries

# %%
# imports
import requests
import os
import pandas as pd

# %% [markdown]
# # Foursquare

# %% [markdown]
# api key with environment

# %%
api_key = os.environ["fsq_api_key"]
# os.environ loads the dictionary with environment variables where os.environ.keys() are all variable names

# %%
location = "Barcelona"

# %% [markdown]
# url of api

# %%
url = "https://api.foursquare.com/v3/places/search?near=" + location

# %% [markdown]
# Send a request to Foursquare with a small radius (1000m) for all the bike stations in your city of choice.

# %%
#url = "https://api.foursquare.com/v3/places/search"
params = {
  	#"query": "coffee",
  	#"ll": "47.606,-122.349358",
  	#"open_now": "true",
  	#"sort":"DISTANCE"
    "radius": "1000"
}

# %%
headers = {
    "Accept": "application/json",
    "Authorization":  api_key
}

# %% [markdown]
# json format results

# %%
result = requests.get(url, headers=headers)
print(result.json())
# Out:
# {'results': [{'fsq_id': '4b631e5ef964a5205e642ae3', 'categories': [{'id': 17018, 'name': 'Bookstore', 'short_name': 'Bookstore', 'plural_name': 'Bookstores', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_', 'suffix': '.png'}}], 'chains': [], 'closed_bucket': 'LikelyOpen', 'distance': 395, 'geocodes': {'main': {'latitude': 41.392076, 'longitude': 2.159978}, 'roof': {'latitude': 41.392076, 'longitude': 2.159978}}, 'link': '/v3/places/4b631e5ef964a5205e642ae3', 'location': {'address': 'Calle Mallorca, 237', 'admin_region': 'Cataluña', 'country': 'ES', 'cross_street': 'C. de Balmes', 'formatted_address': 'Calle Mallorca, 237 (C. de Balmes), 08008 Barcelona Catalunya', 'locality': 'Barcelona', 'postcode': '08008', 'region': 'Catalunya'}, 'name': 'La Central', 'related_places': {'children': []}, 'timezone': 'Europe/Madrid'}, {'fsq_id': '5c4714533ba767002caedd2b', 'categories': [{'id': 13302, 'name': 'Mediterranean Restaurant', 'short_name': 'Mediterranean', 'pl
# ...

# %%
data = result.json()

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
import requests
location = "Barcelona"
url = "https://api.foursquare.com/v3/places/search?near=" + location

#params according to api documentation
params = {
  	# "query": "Barcelona",
    # "sort": "rating",
    # "categories": integer,
  	# "ll": "47.606,-122.349358",
  	# "open_now": "true",
  	# "sort":"DISTANCE"
}

headers = {
    "Accept": "application/json",
    "Authorization": api_key
}

response = requests.request("GET", url, params=params, headers=headers)

print(response.text)
# Out:
# {"results":[{"fsq_id":"4b631e5ef964a5205e642ae3","categories":[{"id":17018,"name":"Bookstore","short_name":"Bookstore","plural_name":"Bookstores","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/shops/bookstore_","suffix":".png"}}],"chains":[],"closed_bucket":"LikelyOpen","distance":395,"geocodes":{"main":{"latitude":41.392076,"longitude":2.159978},"roof":{"latitude":41.392076,"longitude":2.159978}},"link":"/v3/places/4b631e5ef964a5205e642ae3","location":{"address":"Calle Mallorca, 237","admin_region":"Cataluña","country":"ES","cross_street":"C. de Balmes","formatted_address":"Calle Mallorca, 237 (C. de Balmes), 08008 Barcelona Catalunya","locality":"Barcelona","postcode":"08008","region":"Catalunya"},"name":"La Central","related_places":{"children":[]},"timezone":"Europe/Madrid"},{"fsq_id":"5c4714533ba767002caedd2b","categories":[{"id":13302,"name":"Mediterranean Restaurant","short_name":"Mediterranean","plural_name":"Mediterranean Restaurants","icon":{"prefix":"https://ss3.
# ...

# %%
#this puts it in a better form
response.json()
# Out:
# {'results': [{'fsq_id': '4b631e5ef964a5205e642ae3',
#    'categories': [{'id': 17018,
#      'name': 'Bookstore',
#      'short_name': 'Bookstore',
#      'plural_name': 'Bookstores',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 395,
#    'geocodes': {'main': {'latitude': 41.392076, 'longitude': 2.159978},
#     'roof': {'latitude': 41.392076, 'longitude': 2.159978}},
#    'link': '/v3/places/4b631e5ef964a5205e642ae3',
#    'location': {'address': 'Calle Mallorca, 237',
#     'admin_region': 'Cataluña',
#     'country': 'ES',
#     'cross_street': 'C. de Balmes',
#     'formatted_address': 'Calle Mallorca, 237 (C. de Balmes), 08008 Barcelona Catalunya',
#     'locality': 'Barcelona',
#     'postcode': '08008',
#     'region': 'Catalunya'},
#    'name': 'La Central',
#    'related_places': {'children': []},
#    'timezone': 'Europe/Madrid'},
# ...

# %%
response.json().keys()
# Out:
# dict_keys(['results', 'context'])

# %%
response.json()["results"]
# Out:
# [{'fsq_id': '4adcda4cf964a520933f21e3',
#   'categories': [{'id': 19014,
#     'name': 'Hotel',
#     'short_name': 'Hotel',
#     'plural_name': 'Hotels',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#      'suffix': '.png'}}],
#   'chains': [],
#   'closed_bucket': 'VeryLikelyOpen',
#   'distance': 692,
#   'geocodes': {'main': {'latitude': 41.393578, 'longitude': 2.164298}},
#   'link': '/v3/places/4adcda4cf964a520933f21e3',
#   'location': {'address': 'Passeig de Gràcia, 68',
#    'admin_region': 'Cataluña',
#    'country': 'ES',
#    'cross_street': 'València',
#    'formatted_address': 'Passeig de Gràcia, 68 (València), Barcelona Catalunya',
#    'locality': 'Barcelona',
#    'region': 'Catalunya'},
#   'name': 'Majestic Hotel & Spa Barcelona',
#   'related_places': {'children': [{'fsq_id': '4e2ef61cd4c058fdbeeed08b',
#      'categories': [{'id': 13009,
#        'name': 'Cocktail Bar',
#        'short_name': 'Cocktail',
# ...

# %%
response.json()["results"][2].keys()
# Out:
# dict_keys(['fsq_id', 'categories', 'chains', 'closed_bucket', 'distance', 'geocodes', 'link', 'location', 'name', 'related_places', 'timezone'])

# %%
len(response.json()["results"])
# Out:
# 10

# %%
import requests
url = "https://api.foursquare.com/v3/places/search?query=name&near=Barcelona"

headers = {"accept": "application/json", "Authorization": api_key}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"results":[{"fsq_id":"53b3fd74498eeeca1f0e99cc","categories":[{"id":19014,"name":"Hotel","short_name":"Hotel","plural_name":"Hotels","icon":{"prefix":"https://ss3.4sqi.net/img/categories_v2/travel/hotel_","suffix":".png"}}],"chains":[],"closed_bucket":"LikelyOpen","distance":754,"geocodes":{"drop_off":{"latitude":41.382439,"longitude":2.156335},"main":{"latitude":41.382469,"longitude":2.156314},"roof":{"latitude":41.382469,"longitude":2.156314}},"link":"/v3/places/53b3fd74498eeeca1f0e99cc","location":{"address":"Carrer de la Diputació, 113","admin_region":"Cataluña","country":"ES","cross_street":"Comte Borrell","formatted_address":"Carrer de la Diputació, 113 (Comte Borrell), 08015 Barcelona Barcelona","locality":"Barcelona","postcode":"08015","region":"Barcelona"},"name":"NoName","related_places":{},"timezone":"Europe/Madrid"},{"fsq_id":"011462ad208f4b08eb2b2fcd","categories":[{"id":11027,"name":"Computer Repair Service","short_name":"Computer Repair Service","plural_name":"Compute
# ...

# %%
#showing hotels
response.json()
# Out:
# {'results': [{'fsq_id': '53b3fd74498eeeca1f0e99cc',
#    'categories': [{'id': 19014,
#      'name': 'Hotel',
#      'short_name': 'Hotel',
#      'plural_name': 'Hotels',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#       'suffix': '.png'}}],
#    'chains': [],
#    'closed_bucket': 'LikelyOpen',
#    'distance': 754,
#    'geocodes': {'drop_off': {'latitude': 41.382439, 'longitude': 2.156335},
#     'main': {'latitude': 41.382469, 'longitude': 2.156314},
#     'roof': {'latitude': 41.382469, 'longitude': 2.156314}},
#    'link': '/v3/places/53b3fd74498eeeca1f0e99cc',
#    'location': {'address': 'Carrer de la Diputació, 113',
#     'admin_region': 'Cataluña',
#     'country': 'ES',
#     'cross_street': 'Comte Borrell',
#     'formatted_address': 'Carrer de la Diputació, 113 (Comte Borrell), 08015 Barcelona Barcelona',
#     'locality': 'Barcelona',
#     'postcode': '08015',
#     'region': 'Barcelona'},
#    'name': 'NoName',
# ...

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
import pandas as pd
import json

with open('books.json') as f:
    data = json.load(f)

# Use pd.json_normalize to convert the JSON to a DataFrame
df = pd.json_normalize(data['books'], 
                     meta=['title', ['author', 'first_name'], ['author', 'last_name'], ['publisher', 'name'], ['publisher', 'location']])

# Rename the columns for clarity
df.columns = ['Title', 'Author_First_Name', 'Author_Last_Name', 'Publisher_Name', 'Publisher_Location']

# Display the DataFrame
print(df)

# %%
import requests
location = "Barcelona"
url = "https://api.foursquare.com/v3/places/search?near=" + location

params = {
  	# "query": "Barcelona",
    # "sort": "rating",
    # "categories": "Dining and Drinking",
  	# "ll": "47.606,-122.349358",
  	# "open_now": "true",
  	# "sort":"DISTANCE"
}

headers = {
    "Accept": "application/json",
    "Authorization": api_key
}

response = requests.request("GET", url, params=params, headers=headers)

print(response.text)

# %% [markdown]
# # Yelp

# %% [markdown]
# Send a request to Yelp with a small radius (1000m) for all the bike stations in your city of choice.

# %%
# imports
import requests
import os
import pandas as pd

# %%
API_KEY = os.environ.get("YELP_API_KEY")
# os.environ loads the dictionary with environment variables where os.environ.keys() are all variable names

# %%
print(API_KEY)
# Out:
# bYo40wb4nD7EiVkwHb0jg0mH2ZfSUWHzLGPHz1qohZYV2LgT8LOyZv2KVFc_0nrPckGmpIdeX8HOUtjj3sa8hmWQYGwOl_jzY5dvM7DP0PfZJn5kCuJf_FMYrKFuZXYx

# %%
import requests

url = "https://api.yelp.com/v3/businesses/search?location=Barcelona&term=restaurants&radius=1000&categories=&sort_by=best_match&limit=20"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer " + API_KEY
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"businesses": [{"id": "zrxsTCz5lt8q73Hx0GHLDw", "alias": "cerveseria-catalana-barcelona", "name": "Cerveseria Catalana", "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/7UqXBGtaD7F1eovQZ3OtTw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/cerveseria-catalana-barcelona?adjust_creative=sENwaMv9fqBbuWdKP43EwQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=sENwaMv9fqBbuWdKP43EwQ", "review_count": 1564, "categories": [{"alias": "spanish", "title": "Spanish"}], "rating": 4.5, "coordinates": {"latitude": 41.392393, "longitude": 2.160993}, "transactions": [], "price": "\u20ac\u20ac", "location": {"address1": "Carrer de Mallorca, 236", "address2": "", "address3": null, "city": "Barcelona", "zip_code": "08008", "country": "ES", "state": "B", "display_address": ["Carrer de Mallorca, 236", "08008 Barcelona", "Spain"]}, "phone": "+34932160368", "display_phone": "+34 932 16 03 68", "distance": 267.7763219307933}, {"id": "XhNHk-O5Uv2WO_9iFtP_gw", "alias":
# ...

# %%
response.json()
# Out:
# {'businesses': [{'id': 'zrxsTCz5lt8q73Hx0GHLDw',
#    'alias': 'cerveseria-catalana-barcelona',
#    'name': 'Cerveseria Catalana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7UqXBGtaD7F1eovQZ3OtTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cerveseria-catalana-barcelona?adjust_creative=sENwaMv9fqBbuWdKP43EwQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=sENwaMv9fqBbuWdKP43EwQ',
#    'review_count': 1564,
#    'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.392393, 'longitude': 2.160993},
#    'transactions': [],
#    'price': '€€',
#    'location': {'address1': 'Carrer de Mallorca, 236',
#     'address2': '',
#     'address3': None,
#     'city': 'Barcelona',
#     'zip_code': '08008',
#     'country': 'ES',
#     'state': 'B',
#     'display_address': ['Carrer de Mallorca, 236',
#      '08008 Barcelona',
#      'Spain']},
# ...

# %%
import pandas as pd

# Replace the JSON data with your actual JSON data
json_data = {'businesses': [
    {'id': 'zrxsTCz5lt8q73Hx0GHLDw',
     'alias': 'cerveseria-catalana-barcelona',
     'name': 'Cerveseria Catalana',
     'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7UqXBGtaD7F1eovQZ3OtTw/o.jpg',
     'is_closed': False,
     'url': 'https://www.yelp.com/biz/cerveseria-catalana-barcelona?adjust_creative=sENwaMv9fqBbuWdKP43EwQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=sENwaMv9fqBbuWdKP43EwQ',
     'review_count': 1563,
     'categories': [{'alias': 'spanish', 'title': 'Spanish'}],
     'rating': 4.5,
     'coordinates': {'latitude': 41.392393, 'longitude': 2.160993},
     'transactions': [],
     'price': '€€',
     'location': {'address1': 'Carrer de Mallorca, 236',
                  'address2': '',
                  'address3': None,
                  'city': 'Barcelona',
                  'zip_code': '08008',
                  'country': 'ES',
                  'state': 'B',
                  'display_address': ['Carrer de Mallorca, 236',
                                       '08008 Barcelona',
                                       'Spain']},
     'phone': '+34932160368',
     'display_phone': '+34 932 16 03 68',
     'distance': 267.7763219307933}
    # Add more businesses as needed
]}

# Extract the 'businesses' key from the JSON data
businesses_data = json_data['businesses']

# Create a DataFrame from the extracted data
df = pd.DataFrame(businesses_data)

# Display the DataFrame
print(df)
# Out:
#                        id                          alias                 name  \
# 0  zrxsTCz5lt8q73Hx0GHLDw  cerveseria-catalana-barcelona  Cerveseria Catalana
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/7UqXBG...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/cerveseria-catalana-b...          1563
#
#                                    categories  rating  \
# 0  [{'alias': 'spanish', 'title': 'Spanish'}]     4.5
#
#                                       coordinates transactions price  \
# 0  {'latitude': 41.392393, 'longitude': 2.160993}           []    €€
#
#                                             location         phone  \
# 0  {'address1': 'Carrer de Mallorca, 236', 'addre...  +34932160368
#
#       display_phone    distance
# 0  +34 932 16 03 68  267.776322

# %%
data=response.json()

# %% [markdown]
# Parse through the response to get the POI (such as restaurants, bars, etc) details you want (ratings, name, location, etc)

# %%
df = pd.json_normalize(data)

# %%
df.head()
# Out:
#                                           businesses  total  \
# 0  [{'id': 'zrxsTCz5lt8q73Hx0GHLDw', 'alias': 'ce...   1200
#
#    region.center.longitude  region.center.latitude
# 0                 2.163963                41.39148

# %%
df = df[['name', 'review_count', 'city']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\gurmo\Downloads\LHL 2023\-LHL-Statistical-Modelling-Project\notebooks\yelp_foursquare_EDA.ipynb Cell 38 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gurmo/Downloads/LHL%202023/-LHL-Statistical-Modelling-Project/notebooks/yelp_foursquare_EDA.ipynb#X65sZmlsZQ%3D%3D?line=0'>1</a> df = df[['name', 'review_count', 'city']]
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
# ...

# %%
import pandas as pd
import json

with open('books.json') as f:
    data = json.load(f)

# Use pd.json_normalize to convert the JSON to a DataFrame
df = pd.json_normalize(data['books'], 
                     meta=['title', ['author', 'first_name'], ['author', 'last_name'], ['publisher', 'name'], ['publisher', 'location']])

# Rename the columns for clarity
df.columns = ['Title', 'Author_First_Name', 'Author_Last_Name', 'Publisher_Name', 'Publisher_Location']

# Display the DataFrame
print(df)

# %% [markdown]
# Put your parsed results into a DataFrame

# %%
response.json()

# %% [markdown]
# # Comparing Results

# %% [markdown]
# Which API provided you with more complete data? Provide an explanation.

# %% [markdown]
# Get the top 10 restaurants according to their rating
